# %%
from data_loader import *
from data_aug_utils import *

# %%
# dataset_url = "https://www.kaggle.com/datasets/wenewone/cub2002011"
# dataset_url = "https://www.kaggle.com/datasets/jessicali9530/stanford-cars-dataset"
# dataset_url = "https://www.kaggle.com/datasets/pkdarabi/brain-tumor-image-dataset-semantic-segmentation"
# dataset_url = "https://www.kaggle.com/datasets/jessicali9530/stanford-dogs-dataset"
dataset_url = "https://www.kaggle.com/datasets/prasanshasatpathy/soil-types"
target_folder = "."
download_dataset_kaggle(dataset_url, target_folder)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/prasanshasatpathy/soil-types
# '.'

# %%
target_size = (150, 150)
batch_size = 32
folder_name = "/Users/lorenzochicco/Desktop/Progetti/intro-to-ml/utils/CUB_200_2011/images"
train_generator = load_data_from_directory(folder_name, target_size, batch_size)
# Out:
# Found 316 images belonging to 5 classes.

# %%
n_of_batches = 5
savefolder_name = "Soil types"
# Base directory where each class has its own subdirectory
for i, (images, labels) in enumerate(train_generator):
    if i >= n_of_batches:  # Stop after saving images from 50 batches
        break
    save_augmented_images(images, labels, savefolder_name, train_generator.class_indices)

# %%
h = 256
w = 256
resize_images_in_folder(folder_name, h, w)
# Out:
# Resized and saved: Soil types/Cinder Soil/aug_6.png
# Resized and saved: Soil types/Cinder Soil/aug_7.png
# Resized and saved: Soil types/Cinder Soil/aug_5.png
# Resized and saved: Soil types/Cinder Soil/aug_4.png
# Resized and saved: Soil types/Cinder Soil/aug_0.png
# Resized and saved: Soil types/Cinder Soil/aug_1.png
# Resized and saved: Soil types/Cinder Soil/8.jpg
# Resized and saved: Soil types/Cinder Soil/aug_3.png
# Resized and saved: Soil types/Cinder Soil/aug_2.png
# Resized and saved: Soil types/Cinder Soil/9.jpg
# Resized and saved: Soil types/Cinder Soil/14.jpg
# Resized and saved: Soil types/Cinder Soil/28.jpg
# Resized and saved: Soil types/Cinder Soil/aug_14.png
# Resized and saved: Soil types/Cinder Soil/aug_28.png
# Resized and saved: Soil types/Cinder Soil/aug_29.png
# Resized and saved: Soil types/Cinder Soil/aug_15.png
# Resized and saved: Soil types/Cinder Soil/29.jpg
# Resized and saved: Soil types/Cinder Soil/15.jpg
# Resized and saved: Soil types/Cinder Soil/17.jpg
# Resized and saved: Soil types/Cinder Soil/aug_17.png
# Resized and saved: Soil types/Cinder Soil/aug_16.png
# Resized and saved: Soil types/Cinder Soil/16.jpg
# Resized and saved: Soil types/Cinder Soil/12.jpg
# Resized and saved: Soil types/Cinder Soil/aug_12.png
# Resized and saved: Soil types/Cinder Soil/aug_13.png
# Resized and saved: Soil types/Cinder Soil/13.jpg
# Resized and saved: Soil types/Cinder Soil/11.jpg
# Resized and saved: Soil types/Cinder Soil/aug_11.png
# Resized and saved: Soil types/Cinder Soil/aug_10.png
# Resized and saved: Soil types/Cinder Soil/10.jpg
# Resized and saved: Soil types/Cinder Soil/21.jpg
# Resized and saved: Soil types/Cinder Soil/aug_21.png
# Resized and saved: Soil types/Laterite Soil/8.jpg
# Resized and saved: Soil types/Laterite Soil/aug_3.png
# Resized and saved: Soil types/Laterite Soil/aug_2.png
# Resized and saved: Soil types/Laterite Soil/9.jpg
# Resized and saved: Soil types/Laterite Soil/14.jpg
# Resized and saved: Soil types/Laterite Soil/28.jpg
# Resized and saved: Soil types/Laterite Soil/aug_14.png
# Resized and saved: Soil types/Laterite Soil/aug_28.png
# Resized and saved: Soil types/Laterite Soil/aug_29.png
# Resized and saved: Soil types/Laterite Soil/aug_15.png
# Resized and saved: Soil types/Laterite Soil/29.jpg
# Resized and saved: Soil types/Laterite Soil/15.jpg
# Resized and saved: Soil types/Laterite Soil/17.jpg
# Resized and saved: Soil types/Laterite Soil/aug_17.png
# Resized and saved: Soil types/Laterite Soil/aug_16.png
# Resized and saved: Soil types/Laterite Soil/16.jpg
# Resized and saved: Soil types/Laterite Soil/12.jpg
# Resized and saved: Soil types/Laterite Soil/aug_12.png
# Resized and saved: Soil types/Laterite Soil/aug_13.png
# Resized and saved: Soil types/Laterite Soil/13.jpg
# Resized and saved: Soil types/Laterite Soil/11.jpg
# Resized and saved: Soil types/Laterite Soil/aug_11.png
# Resized and saved: Soil types/Laterite Soil/aug_10.png
# Resized and saved: Soil types/Laterite Soil/10.jpg
# Resized and saved: Soil types/Laterite Soil/21.jpg
# Resized and saved: Soil types/Laterite Soil/aug_21.png
# Resized and saved: Soil types/Laterite Soil/aug_20.png
# Resized and saved: Soil types/Laterite Soil/20.jpg
# Resized and saved: Soil types/Laterite Soil/22.jpg
# Resized and saved: Soil types/Laterite Soil/aug_22.png
# Resized and saved: Soil types/Laterite Soil/aug_23.png
# Resized and saved: Soil types/Laterite Soil/23.jpg
# Resized and saved: Soil types/Laterite Soil/27.jpg
# Resized and saved: Soil types/Laterite Soil/aug_27.png
# Resized and saved: Soil types/Laterite Soil/aug_26.png
# Resized and saved: Soil types/Laterite Soil/26.jpg
# Resized and saved: Soil types/Laterite Soil/18.jpg
# Resized and saved: Soil types/Laterite Soil/24.jpg
# Resized and saved: Soil types/Laterite Soil/30.jpg
# Resized and saved: Soil types/Laterite Soil/aug_18.png
# Resized and saved: Soil types/Laterite Soil/aug_24.png
# Resized and saved: Soil types/Laterite Soil/aug_30.png
# Resized and saved: Soil types/Laterite Soil/aug_31.png
# Resized and saved: Soil types/Laterite Soil/aug_25.png
# Resized and saved: Soil types/Laterite Soil/aug_19.png
# Resized and saved: Soil types/Laterite Soil/25.jpg
# Resized and saved: Soil types/Laterite Soil/19.jpg
# Resized and saved: Soil types/Laterite Soil/4.jpg
# Resized and saved: Soil types/Laterite Soil/5.jpg
# Resized and saved: Soil types/Laterite Soil/7.jpg
# Resized and saved: Soil types/Laterite Soil/6.jpg
# Resized and saved: Soil types/Laterite Soil/2.jpg
# Resized and saved: Soil types/Laterite Soil/aug_9.png
# Resized and saved: Soil types/Peat Soil/4.jpg
# Resized and saved: Soil types/Peat Soil/5.jpg
# Resized and saved: Soil types/Peat Soil/7.jpg
# Resized and saved: Soil types/Peat Soil/6.jpg
# Resized and saved: Soil types/Peat Soil/2.jpg
# Resized and saved: Soil types/Peat Soil/aug_9.png
# Resized and saved: Soil types/Peat Soil/aug_8.png
# Resized and saved: Soil types/Peat Soil/3.jpg
# Resized and saved: Soil types/Peat Soil/1.jpg

# %%
dataset_url = "https://www.kaggle.com/datasets/wenewone/cub2002011"
target_folder = "."
download_dataset_kaggle(dataset_url, target_folder)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/wenewone/cub2002011
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 3
#       1 dataset_url = "https://www.kaggle.com/datasets/wenewone/cub2002011"
#       2 target_folder = "."
# ----> 3 download_dataset_kaggle(dataset_url, target_folder)
#
# File ~/Desktop/Progetti/intro-to-ml/utils/data_loader.py:32, in download_dataset_kaggle(dataset_url, target_folder)
#      29 kaggle_dataset = f'{owner}/{dataset_name}'
#      31 # Changing the working directory to the target folder
# ---> 32 os.chdir(target_folder)
#      34 # Using the Kaggle API to download the dataset
#      35 # Make sure Place the kaggle.json file in the location ~/.kaggle/kaggle.json on Unix-based systems or
#      36 # C:\Users\<Windows-username>\.kaggle\kaggle.json on Windows.
#      37 # This allows the API client to automatically recognize your credentials.
#      38 kaggle.api.dataset_download_files(kaggle_dataset, path=target_folder, unzip=True)
#
# File ~/Desktop/Progetti/intro-to-ml/augment_venv/lib/python3.12/site-packages/kaggle/api/kaggle_api_extended.py:1473, in KaggleApi.dataset_download_files(self, dataset, path, force, quiet, unzip, licenses)
#    1471 try:
#    1472     with zipfile.ZipFile(outfile) as z:
# -> 1473         z.extractall(effective_path)
#    1474 except zipfile.BadZipFile as e:
#    1475     raise ValueError(
#    1476         'Bad zip file, please report on '
#    1477         'www.github.com/kaggle/kaggle-api', e)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/zipfile/__init__.py:1720, in ZipFile.extractall(self, path, members, pwd)
#    1717     path = os.fspath(path)
#    1719 for zipinfo in members:
# -> 1720     self._extract_member(zipinfo, path, pwd)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/zipfile/__init__.py:1763, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1760 if not arcname:
#    1761     raise ValueError("Empty filename.")
# -> 1763 targetpath = os.path.join(targetpath, arcname)
#    1764 targetpath = os.path.normpath(targetpath)
#    1766 # Create all upper directories if necessary.
#
# File <frozen posixpath>:88, in join(a, *p)
#
# KeyboardInterrupt:

# %%
target_size = (150, 150)
batch_size = 32
folder_name = "/Users/lorenzochicco/Desktop/Progetti/intro-to-ml/utils/CUB_200_2011/images"
train_generator = load_data_from_directory(folder_name, target_size, batch_size)
# Out:
# Found 11788 images belonging to 200 classes.

# %%
n_of_batches = 5
savefolder_name = folder_name
# Base directory where each class has its own subdirectory
for i, (images, labels) in enumerate(train_generator):
    if i >= n_of_batches:  # Stop after saving images from 50 batches
        break
    save_augmented_images(images, labels, savefolder_name, train_generator.class_indices)
